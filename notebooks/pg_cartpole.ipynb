# %% [markdown]
# # Implementing Policy Gradients on CartPole with PyTorch

# %%
import gym
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm, trange
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable
from torch.distributions import Categorical
# %matplotlib inline

# %%
env = gym.make('CartPole-v1')
env.seed(1); torch.manual_seed(1);

# %% [markdown]
# ## Policy Gradients
# A policy gradient attempts to train an agent without explicitly mapping the value for every state-action pair in an environment by taking small steps and updating the policy based on the reward associated with that step. The agent can receive a reward immediately for an action or the agent can receive the award at a later time such as the end of the episode.
# We’ll designate the policy function our agent is trying to learn as $\pi_\theta(a,s)$, where $\theta$ is the parameter vector, $s$ is a particular state, and $a$ is an action.
#
# We'll apply a technique called Monte-Carlo Policy Gradient which means we will have the agent run through an entire episode and then update our policy based on the rewards obtained.

# %% [markdown]
# ## Model Construction
# ### Create Neural Network Model
# We will use a simple feed forward neural network with one hidden layer of 128 neurons and a dropout of 0.6.  We'll use Adam as our optimizer and a learning rate of 0.01.  Using dropout will significantly improve the performance of our policy.  I encourage you to compare results with and without dropout and experiment with other hyper-parameter values.

# %%
#Hyperparameters
learning_rate = 0.01
gamma = 0.99

# %%
class Policy(nn.Module):
    def __init__(self):
        super(Policy, self).__init__()
        self.state_space = env.observation_space.shape[0]
        self.action_space = env.action_space.n
        
        self.l1 = nn.Linear(self.state_space, 128, bias=False)
        self.l2 = nn.Linear(128, self.action_space, bias=False)
        
        self.gamma = gamma
        
        # Episode policy and reward history 
        self.policy_history = Variable(torch.Tensor()) 
        self.reward_episode = []
        # Overall reward and loss history
        self.reward_history = []
        self.loss_history = []

    def forward(self, x):    
        model = torch.nn.Sequential(
            self.l1,
            nn.Dropout(p=0.6),
            nn.ReLU(),
            self.l2,
            nn.Softmax(dim=-1)
        )
        return model(x)

# %%
policy = Policy()
optimizer = optim.Adam(policy.parameters(), lr=learning_rate)

# %% [markdown]
# ### Select Action
# The select_action function chooses an action based on our policy probability distribution using the PyTorch distributions package.  Our policy returns a probability for each possible action in our action space (move left or move right) as an array of length two such as [0.7, 0.3].  We then choose an action based on these probabilities, record our history, and return our action.

# %%
def select_action(state):
    #Select an action (0 or 1) by running policy model and choosing based on the probabilities in state
    state = torch.from_numpy(state).type(torch.FloatTensor)
    state = policy(Variable(state))
    c = Categorical(state)
    #action = c.sample()
    action = c.probs.argmax()
    
    # Add log probability of our chosen action to our history    
    if policy.policy_history.dim() != 0 and policy.policy_history.size() > torch.Size([0]):
        policy.policy_history = torch.cat([policy.policy_history, c.log_prob(action)])
    else:
        policy.policy_history = (c.log_prob(action))
    return action

# %% [markdown]
# ### Reward $v_t$
# We update our policy by taking a sample of the action value function $Q^{\pi_\theta} (s_t,a_t)$ by playing through episodes of the game.  $Q^{\pi_\theta} (s_t,a_t)$ is defined as the expected return by taking action $a$ in state $s$ following policy $\pi$.
#
# We know that for every step the simulation continues we receive a reward of 1.  We can use this to calculate the policy gradient at each time step, where $r$ is the reward for a particular state-action pair.  Rather than using the instantaneous reward, $r$, we instead use a long term reward $ v_{t} $ where $v_t$ is the discounted sum of all future rewards for the length of the episode.  In this way, the **longer** the episode runs into the future, the **greater** the reward for a particular state-action pair in the present. $v_{t}$ is then,
#
# $$ v_{t} = \sum_{k=0}^{N} \gamma^{k}r_{t+k} $$
#
# where $\gamma$ is the discount factor (0.99).  For example, if an episode lasts 5 steps, the reward for each step will be [4.90, 3.94, 2.97, 1.99, 1].
# Next we scale our reward vector by substracting the mean from each element and scaling to unit variance by dividing by the standard deviation.  This practice is common for machine learning applications and the same operation as Scikit Learn's __[StandardScaler](http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html)__.  It also has the effect of compensating for future uncertainty.
#
# ## Update Policy
# After each episode we apply Monte-Carlo Policy Gradient to improve our policy according to the equation:
#
# $$\Delta\theta_t = \alpha\nabla_\theta \, \log \pi_\theta (s_t,a_t)v_t  $$
#
# We will then feed our policy history multiplied by our rewards to our optimizer and update the weights of our neural network using stochastic gradent *ascent*.  This should increase the likelihood of actions that got our agent a larger reward.

# %%
def update_policy():
    R = 0
    rewards = []
    
    # Discount future rewards back to the present using gamma
    for r in policy.reward_episode[::-1]:
        R = r + policy.gamma * R
        rewards.insert(0,R)
        
    # Scale rewards
    rewards = torch.FloatTensor(rewards)
    rewards = (rewards - rewards.mean()) / (rewards.std() + np.finfo(np.float32).eps)
    
    # Calculate loss
    loss = (torch.sum(torch.mul(policy.policy_history, Variable(rewards)).mul(-1), -1))
    
    # Update network weights
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    #Save and intialize episode history counters
    policy.loss_history.append(loss.data.item())
    policy.reward_history.append(np.sum(policy.reward_episode))
    policy.policy_history = Variable(torch.Tensor())
    policy.reward_episode= []

# %% [markdown]
# ### Training
# This is our main policy training loop.  For each step in a training episode, we choose an action, take a step through the environment, and record the resulting new state and reward.  We call update_policy() at the end of each episode to feed the episode history to our neural network and improve our policy.

# %%
def main(episodes):
    running_reward = 10
    for episode in range(episodes):
        state = env.reset() # Reset environment and record the starting state
        done = False       
    
        for time in range(1000):
            action = select_action(state)
            # Step through environment using chosen action
            state, reward, done, _ = env.step(action.data.item())

            # Save reward
            policy.reward_episode.append(reward)
            if done:
                break
        
        # Used to determine when the environment is solved.
        running_reward = (running_reward * 0.99) + (time * 0.01)

        update_policy()

        if episode % 50 == 0:
            print('Episode {}\tLast length: {:5d}\tAverage length: {:.2f}'.format(episode, time, running_reward))

        if running_reward > env.spec.reward_threshold:
            print("Solved! Running reward is now {} and the last episode runs to {} time steps!".format(running_reward, time))
            break

# %% [markdown]
# ## Run Model

# %%
episodes = 1000
main(episodes)
# Out:
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# Episode 0	Last length:    10	Average length: 10.00
# tensor(7.1054e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(1.8626e-09, grad_fn=<SumBackward2>)
# tensor(-2.5580e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(2.8422e-14, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-4.5475e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(0., grad_fn=<SumBackward2>)
# tensor(-1.1642e-09, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(2.8422e-14, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-5.9605e-08, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-2.8422e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-2.5580e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(1.4901e-07, grad_fn=<SumBackward2>)
# tensor(-3.7253e-08, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.4552e-11, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# Episode 50	Last length:    10	Average length: 10.01
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-2.2737e-13, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-9.0949e-13, grad_fn=<SumBackward2>)
# tensor(9.9476e-14, grad_fn=<SumBackward2>)
# tensor(-4.0745e-10, grad_fn=<SumBackward2>)
# tensor(-2.7285e-12, grad_fn=<SumBackward2>)
# tensor(-2.3283e-10, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(4.6566e-10, grad_fn=<SumBackward2>)
# tensor(-4.5475e-12, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(1.7462e-10, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(3.2685e-13, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-7.9581e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-3.8369e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(2.0464e-12, grad_fn=<SumBackward2>)
# tensor(-1.4901e-08, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-3.4106e-13, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-7.1526e-07, grad_fn=<SumBackward2>)
# tensor(2.7285e-12, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.0914e-11, grad_fn=<SumBackward2>)
# tensor(1.2733e-11, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-4.4703e-08, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(2.9802e-08, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(2.8422e-14, grad_fn=<SumBackward2>)
# Episode 100	Last length:    15	Average length: 10.16
# tensor(7.1054e-14, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-2.7001e-13, grad_fn=<SumBackward2>)
# tensor(2.7001e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-2.7001e-13, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(0., grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-2.3842e-07, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(8.9407e-08, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-3.2742e-11, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-2.7285e-12, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(7.1054e-14, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.8474e-13, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(5.2387e-10, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-2.8312e-07, grad_fn=<SumBackward2>)
# tensor(-1.8474e-13, grad_fn=<SumBackward2>)
# tensor(0., grad_fn=<SumBackward2>)
# tensor(-2.3647e-11, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.7053e-13, grad_fn=<SumBackward2>)
# tensor(-3.7253e-09, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-4.1723e-07, grad_fn=<SumBackward2>)
# tensor(5.6843e-13, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(1.0914e-11, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(1.9895e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-4.6566e-10, grad_fn=<SumBackward2>)
# tensor(-2.0955e-09, grad_fn=<SumBackward2>)
# Episode 150	Last length:    13	Average length: 10.46
# tensor(-8.9407e-08, grad_fn=<SumBackward2>)
# tensor(-2.7001e-13, grad_fn=<SumBackward2>)
# tensor(8.1956e-08, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(1.0004e-10, grad_fn=<SumBackward2>)
# tensor(-1.4552e-11, grad_fn=<SumBackward2>)
# tensor(-5.9605e-08, grad_fn=<SumBackward2>)
# tensor(1.3970e-09, grad_fn=<SumBackward2>)
# tensor(-3.4925e-10, grad_fn=<SumBackward2>)
# tensor(-1.7053e-13, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(1.3970e-09, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(1.1176e-08, grad_fn=<SumBackward2>)
# tensor(3.1264e-13, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(0., grad_fn=<SumBackward2>)
# tensor(2.8422e-14, grad_fn=<SumBackward2>)
# tensor(4.2064e-12, grad_fn=<SumBackward2>)
# tensor(3.7253e-07, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-3.1264e-13, grad_fn=<SumBackward2>)
# tensor(9.9476e-14, grad_fn=<SumBackward2>)
# tensor(2.2352e-08, grad_fn=<SumBackward2>)
# tensor(-7.4506e-08, grad_fn=<SumBackward2>)
# tensor(-5.3644e-07, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-3.8369e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(2.3283e-10, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(7.4506e-08, grad_fn=<SumBackward2>)
# tensor(7.1054e-14, grad_fn=<SumBackward2>)
# tensor(7.1054e-14, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-3.2783e-07, grad_fn=<SumBackward2>)
# tensor(7.1054e-14, grad_fn=<SumBackward2>)
# tensor(1.1642e-10, grad_fn=<SumBackward2>)
# tensor(-4.7684e-07, grad_fn=<SumBackward2>)
# tensor(-2.0464e-12, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# Episode 200	Last length:     9	Average length: 11.78
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(-1.8474e-13, grad_fn=<SumBackward2>)
# tensor(-1.8474e-13, grad_fn=<SumBackward2>)
# tensor(0., grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-2.3842e-07, grad_fn=<SumBackward2>)
# tensor(6.7521e-09, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-2.7001e-13, grad_fn=<SumBackward2>)
# tensor(1.9895e-13, grad_fn=<SumBackward2>)
# tensor(-5.4570e-12, grad_fn=<SumBackward2>)
# tensor(-3.1264e-13, grad_fn=<SumBackward2>)
# tensor(7.4506e-08, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(-1.2733e-11, grad_fn=<SumBackward2>)
# tensor(2.9802e-08, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(2.3283e-10, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(1.9895e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-7.2760e-12, grad_fn=<SumBackward2>)
# tensor(-1.8474e-13, grad_fn=<SumBackward2>)
# tensor(8.5265e-14, grad_fn=<SumBackward2>)
# tensor(-1.8190e-12, grad_fn=<SumBackward2>)
# tensor(-3.4925e-10, grad_fn=<SumBackward2>)
# tensor(-1.8474e-13, grad_fn=<SumBackward2>)
# tensor(4.0978e-08, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-1.8474e-13, grad_fn=<SumBackward2>)
# tensor(-1.8474e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-3.5016e-11, grad_fn=<SumBackward2>)
# tensor(-2.7001e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(7.1054e-14, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-2.3283e-09, grad_fn=<SumBackward2>)
# tensor(-4.0745e-10, grad_fn=<SumBackward2>)
# tensor(-3.5763e-07, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(1.3411e-06, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# Episode 250	Last length:     8	Average length: 12.32
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(4.9113e-11, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(4.7684e-07, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-1.3642e-12, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(8.5265e-14, grad_fn=<SumBackward2>)
# tensor(-1.7462e-10, grad_fn=<SumBackward2>)
# tensor(2.2352e-07, grad_fn=<SumBackward2>)
# tensor(-4.1723e-07, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-2.7001e-13, grad_fn=<SumBackward2>)
# tensor(1.3970e-09, grad_fn=<SumBackward2>)
# tensor(7.1054e-14, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.8474e-13, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(0., grad_fn=<SumBackward2>)
# tensor(-1.8626e-08, grad_fn=<SumBackward2>)
# tensor(3.8199e-11, grad_fn=<SumBackward2>)
# tensor(6.8212e-13, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-2.5580e-13, grad_fn=<SumBackward2>)
# tensor(-1.1369e-13, grad_fn=<SumBackward2>)
# tensor(-1.8474e-13, grad_fn=<SumBackward2>)
# tensor(-4.5475e-12, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(2.8422e-14, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(1.0914e-11, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(0., grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.8474e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.7462e-09, grad_fn=<SumBackward2>)
# tensor(-1.8474e-13, grad_fn=<SumBackward2>)
# Episode 300	Last length:    27	Average length: 12.44
# tensor(0., grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.7053e-13, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(3.4925e-10, grad_fn=<SumBackward2>)
# tensor(7.4506e-08, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(5.8208e-11, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(2.8422e-14, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-3.8369e-13, grad_fn=<SumBackward2>)
# tensor(1.1369e-13, grad_fn=<SumBackward2>)
# tensor(1.2278e-11, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(4.8317e-13, grad_fn=<SumBackward2>)
# tensor(2.4214e-08, grad_fn=<SumBackward2>)
# tensor(1.8190e-12, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(8.6686e-13, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(2.8422e-14, grad_fn=<SumBackward2>)
# tensor(-5.9605e-08, grad_fn=<SumBackward2>)
# tensor(2.9802e-08, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(3.0268e-09, grad_fn=<SumBackward2>)
# tensor(7.1054e-14, grad_fn=<SumBackward2>)
# tensor(-1.1921e-07, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-1.7462e-10, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(7.8580e-10, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(2.0862e-07, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-5.3644e-07, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(4.6566e-10, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-2.9802e-08, grad_fn=<SumBackward2>)
# tensor(-4.7294e-11, grad_fn=<SumBackward2>)
# Episode 350	Last length:    17	Average length: 12.63
# tensor(2.9104e-10, grad_fn=<SumBackward2>)
# tensor(1.0914e-11, grad_fn=<SumBackward2>)
# tensor(-8.7311e-11, grad_fn=<SumBackward2>)
# tensor(2.8422e-14, grad_fn=<SumBackward2>)
# tensor(-2.7001e-13, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(1.1921e-07, grad_fn=<SumBackward2>)
# tensor(2.7001e-13, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.1369e-13, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(9.0949e-13, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(5.8265e-13, grad_fn=<SumBackward2>)
# tensor(1.8190e-12, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-8.1956e-08, grad_fn=<SumBackward2>)
# tensor(-5.5879e-09, grad_fn=<SumBackward2>)
# tensor(2.9104e-11, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(-3.1264e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(1.0729e-06, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.0431e-07, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(-5.8208e-11, grad_fn=<SumBackward2>)
# tensor(-9.0949e-12, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(1.1921e-07, grad_fn=<SumBackward2>)
# tensor(1.4156e-07, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(5.5879e-09, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-3.7253e-09, grad_fn=<SumBackward2>)
# tensor(-7.9581e-13, grad_fn=<SumBackward2>)
# tensor(-1.8474e-13, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-5.8208e-11, grad_fn=<SumBackward2>)
# Episode 400	Last length:     9	Average length: 12.60
# tensor(3.4273e-07, grad_fn=<SumBackward2>)
# tensor(2.8422e-14, grad_fn=<SumBackward2>)
# tensor(-1.0914e-11, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-1.3411e-07, grad_fn=<SumBackward2>)
# tensor(5.6843e-14, grad_fn=<SumBackward2>)
# tensor(7.1054e-14, grad_fn=<SumBackward2>)
# tensor(1.9895e-13, grad_fn=<SumBackward2>)
# tensor(5.2387e-10, grad_fn=<SumBackward2>)
# tensor(1.8190e-11, grad_fn=<SumBackward2>)
# tensor(1.8626e-09, grad_fn=<SumBackward2>)
# tensor(2.8422e-14, grad_fn=<SumBackward2>)
# tensor(9.3132e-09, grad_fn=<SumBackward2>)
# tensor(-3.4106e-12, grad_fn=<SumBackward2>)
# tensor(4.2633e-13, grad_fn=<SumBackward2>)
# tensor(-9.0949e-13, grad_fn=<SumBackward2>)
# tensor(-3.8369e-13, grad_fn=<SumBackward2>)
# tensor(-3.6380e-12, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-3.6380e-11, grad_fn=<SumBackward2>)
# tensor(-7.4506e-09, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(3.6508e-07, grad_fn=<SumBackward2>)
# tensor(-9.0949e-12, grad_fn=<SumBackward2>)
# tensor(8.9407e-08, grad_fn=<SumBackward2>)
# tensor(-3.6380e-12, grad_fn=<SumBackward2>)
# tensor(-7.2760e-12, grad_fn=<SumBackward2>)
# tensor(2.7001e-13, grad_fn=<SumBackward2>)
# tensor(-1.8474e-13, grad_fn=<SumBackward2>)
# tensor(-1.7053e-13, grad_fn=<SumBackward2>)
# tensor(6.2528e-13, grad_fn=<SumBackward2>)
# tensor(-1.7053e-13, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.8474e-13, grad_fn=<SumBackward2>)
# tensor(4.6566e-10, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-1.1921e-07, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-4.7294e-11, grad_fn=<SumBackward2>)
# tensor(2.8422e-14, grad_fn=<SumBackward2>)
# tensor(-2.9843e-13, grad_fn=<SumBackward2>)
# tensor(2.3283e-10, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(1.1921e-07, grad_fn=<SumBackward2>)
# tensor(1.8190e-11, grad_fn=<SumBackward2>)
# tensor(-3.1264e-13, grad_fn=<SumBackward2>)
# Episode 450	Last length:    18	Average length: 14.03
# tensor(1.2517e-06, grad_fn=<SumBackward2>)
# tensor(-8.1956e-08, grad_fn=<SumBackward2>)
# tensor(7.1054e-14, grad_fn=<SumBackward2>)
# tensor(2.8422e-14, grad_fn=<SumBackward2>)
# tensor(-5.9605e-08, grad_fn=<SumBackward2>)
# tensor(-2.5611e-09, grad_fn=<SumBackward2>)
# tensor(7.1054e-14, grad_fn=<SumBackward2>)
# tensor(-4.6194e-07, grad_fn=<SumBackward2>)
# tensor(1.3097e-10, grad_fn=<SumBackward2>)
# tensor(2.3842e-07, grad_fn=<SumBackward2>)
# tensor(5.2154e-08, grad_fn=<SumBackward2>)
# tensor(-2.2737e-13, grad_fn=<SumBackward2>)
# tensor(7.1054e-14, grad_fn=<SumBackward2>)
# tensor(9.0949e-13, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.0914e-11, grad_fn=<SumBackward2>)
# tensor(-1.8626e-08, grad_fn=<SumBackward2>)
# tensor(9.3132e-10, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.1921e-07, grad_fn=<SumBackward2>)
# tensor(1.0914e-11, grad_fn=<SumBackward2>)
# tensor(2.8422e-14, grad_fn=<SumBackward2>)
# tensor(1.4552e-10, grad_fn=<SumBackward2>)
# tensor(2.7285e-12, grad_fn=<SumBackward2>)
# tensor(-3.8369e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(6.7055e-08, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(2.8422e-14, grad_fn=<SumBackward2>)
# tensor(3.5763e-07, grad_fn=<SumBackward2>)
# tensor(-9.3132e-09, grad_fn=<SumBackward2>)
# tensor(-7.0941e-11, grad_fn=<SumBackward2>)
# tensor(-3.2037e-07, grad_fn=<SumBackward2>)
# tensor(8.9407e-08, grad_fn=<SumBackward2>)
# tensor(-7.1526e-07, grad_fn=<SumBackward2>)
# tensor(-7.7486e-07, grad_fn=<SumBackward2>)
# tensor(3.4273e-07, grad_fn=<SumBackward2>)
# tensor(-3.8369e-13, grad_fn=<SumBackward2>)
# tensor(-4.7684e-07, grad_fn=<SumBackward2>)
# tensor(1.1176e-08, grad_fn=<SumBackward2>)
# tensor(-1.0431e-07, grad_fn=<SumBackward2>)
# tensor(2.9104e-11, grad_fn=<SumBackward2>)
# tensor(4.6566e-09, grad_fn=<SumBackward2>)
# tensor(2.8422e-14, grad_fn=<SumBackward2>)
# tensor(-2.5580e-13, grad_fn=<SumBackward2>)
# tensor(2.8422e-14, grad_fn=<SumBackward2>)
# tensor(7.1054e-14, grad_fn=<SumBackward2>)
# tensor(-1.4901e-08, grad_fn=<SumBackward2>)
# tensor(-9.0949e-12, grad_fn=<SumBackward2>)
# Episode 500	Last length:    52	Average length: 16.39
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(1.1141e-11, grad_fn=<SumBackward2>)
# tensor(-5.9605e-08, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-3.6948e-13, grad_fn=<SumBackward2>)
# tensor(0., grad_fn=<SumBackward2>)
# tensor(2.8422e-14, grad_fn=<SumBackward2>)
# tensor(1.7881e-07, grad_fn=<SumBackward2>)
# tensor(1.1369e-13, grad_fn=<SumBackward2>)
# tensor(-1.8190e-12, grad_fn=<SumBackward2>)
# tensor(2.1828e-11, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(5.8208e-11, grad_fn=<SumBackward2>)
# tensor(2.7001e-13, grad_fn=<SumBackward2>)
# tensor(-4.3656e-11, grad_fn=<SumBackward2>)
# tensor(-3.0850e-09, grad_fn=<SumBackward2>)
# tensor(-1.2806e-09, grad_fn=<SumBackward2>)
# tensor(-5.6843e-14, grad_fn=<SumBackward2>)
# tensor(-1.7644e-10, grad_fn=<SumBackward2>)
# tensor(-8.5265e-14, grad_fn=<SumBackward2>)
# tensor(1.9372e-07, grad_fn=<SumBackward2>)
# tensor(-4.6566e-10, grad_fn=<SumBackward2>)
# tensor(9.4587e-11, grad_fn=<SumBackward2>)
# tensor(1.4901e-08, grad_fn=<SumBackward2>)
# tensor(-1.6391e-07, grad_fn=<SumBackward2>)
# tensor(-4.1723e-07, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(8.1002e-13, grad_fn=<SumBackward2>)
# tensor(9.9476e-14, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(7.7486e-07, grad_fn=<SumBackward2>)
# tensor(-1.8190e-12, grad_fn=<SumBackward2>)
# tensor(1.8179e-06, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(-1.1176e-08, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(-2.0373e-10, grad_fn=<SumBackward2>)
# tensor(7.1054e-14, grad_fn=<SumBackward2>)
# tensor(2.6077e-08, grad_fn=<SumBackward2>)
# tensor(-2.2737e-12, grad_fn=<SumBackward2>)
# tensor(1.0186e-10, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-5.5879e-09, grad_fn=<SumBackward2>)
# tensor(-2.9843e-13, grad_fn=<SumBackward2>)
# tensor(-1.8474e-13, grad_fn=<SumBackward2>)
# tensor(-1.8190e-12, grad_fn=<SumBackward2>)
# tensor(-3.1264e-13, grad_fn=<SumBackward2>)
# Episode 550	Last length:    18	Average length: 18.11
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(6.8212e-13, grad_fn=<SumBackward2>)
# tensor(2.9802e-08, grad_fn=<SumBackward2>)
# tensor(-4.7748e-12, grad_fn=<SumBackward2>)
# tensor(-5.9605e-07, grad_fn=<SumBackward2>)
# tensor(-1.0914e-10, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(2.8422e-14, grad_fn=<SumBackward2>)
# tensor(0., grad_fn=<SumBackward2>)
# tensor(6.4028e-10, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(7.1054e-14, grad_fn=<SumBackward2>)
# tensor(2.8422e-14, grad_fn=<SumBackward2>)
# tensor(-3.8369e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(-2.7001e-13, grad_fn=<SumBackward2>)
# tensor(-1.1176e-08, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-1.4552e-11, grad_fn=<SumBackward2>)
# tensor(8.6686e-13, grad_fn=<SumBackward2>)
# tensor(2.8422e-14, grad_fn=<SumBackward2>)
# tensor(4.1723e-07, grad_fn=<SumBackward2>)
# tensor(0., grad_fn=<SumBackward2>)
# tensor(-5.4570e-12, grad_fn=<SumBackward2>)
# tensor(-7.9581e-13, grad_fn=<SumBackward2>)
# tensor(7.1054e-14, grad_fn=<SumBackward2>)
# tensor(1.3824e-10, grad_fn=<SumBackward2>)
# tensor(-1.1176e-08, grad_fn=<SumBackward2>)
# tensor(1.0431e-07, grad_fn=<SumBackward2>)
# tensor(4.0927e-12, grad_fn=<SumBackward2>)
# tensor(-3.2783e-07, grad_fn=<SumBackward2>)
# tensor(-1.5916e-12, grad_fn=<SumBackward2>)
# tensor(-3.1264e-13, grad_fn=<SumBackward2>)
# tensor(-6.9849e-09, grad_fn=<SumBackward2>)
# tensor(1.4901e-08, grad_fn=<SumBackward2>)
# tensor(-2.7001e-13, grad_fn=<SumBackward2>)
# tensor(3.6380e-12, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(3.0559e-10, grad_fn=<SumBackward2>)
# tensor(-6.8212e-13, grad_fn=<SumBackward2>)
# tensor(9.9476e-14, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(6.8212e-13, grad_fn=<SumBackward2>)
# tensor(-2.0009e-11, grad_fn=<SumBackward2>)
# tensor(2.2119e-09, grad_fn=<SumBackward2>)
# tensor(2.8422e-14, grad_fn=<SumBackward2>)
# Episode 600	Last length:    15	Average length: 17.16
# tensor(-2.7001e-13, grad_fn=<SumBackward2>)
# tensor(7.3896e-13, grad_fn=<SumBackward2>)
# tensor(7.1054e-14, grad_fn=<SumBackward2>)
# tensor(-1.8474e-13, grad_fn=<SumBackward2>)
# tensor(-2.2352e-08, grad_fn=<SumBackward2>)
# tensor(6.5193e-09, grad_fn=<SumBackward2>)
# tensor(-1.7053e-13, grad_fn=<SumBackward2>)
# tensor(1.9895e-13, grad_fn=<SumBackward2>)
# tensor(2.2352e-08, grad_fn=<SumBackward2>)
# tensor(-1.8474e-13, grad_fn=<SumBackward2>)
# tensor(-1.1921e-07, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(7.5670e-10, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(7.1054e-14, grad_fn=<SumBackward2>)
# tensor(3.2783e-07, grad_fn=<SumBackward2>)
# tensor(-3.1264e-13, grad_fn=<SumBackward2>)
# tensor(-4.6566e-10, grad_fn=<SumBackward2>)
# tensor(0., grad_fn=<SumBackward2>)
# tensor(-9.0949e-12, grad_fn=<SumBackward2>)
# tensor(-2.7001e-13, grad_fn=<SumBackward2>)
# tensor(7.4506e-09, grad_fn=<SumBackward2>)
# tensor(-3.1264e-13, grad_fn=<SumBackward2>)
# tensor(6.2528e-13, grad_fn=<SumBackward2>)
# tensor(2.7001e-13, grad_fn=<SumBackward2>)
# tensor(-3.0268e-09, grad_fn=<SumBackward2>)
# tensor(1.0058e-07, grad_fn=<SumBackward2>)
# tensor(3.7253e-08, grad_fn=<SumBackward2>)
# tensor(1.7881e-07, grad_fn=<SumBackward2>)
# tensor(-9.8225e-11, grad_fn=<SumBackward2>)
# tensor(-3.4925e-09, grad_fn=<SumBackward2>)
# tensor(-4.0927e-12, grad_fn=<SumBackward2>)
# tensor(1.0477e-08, grad_fn=<SumBackward2>)
# tensor(-7.9162e-09, grad_fn=<SumBackward2>)
# tensor(1.0186e-10, grad_fn=<SumBackward2>)
# tensor(-3.8369e-13, grad_fn=<SumBackward2>)
# tensor(-7.9581e-13, grad_fn=<SumBackward2>)
# tensor(5.5422e-13, grad_fn=<SumBackward2>)
# tensor(1.3388e-09, grad_fn=<SumBackward2>)
# tensor(-3.1264e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(-1.8474e-13, grad_fn=<SumBackward2>)
# tensor(-1.7462e-09, grad_fn=<SumBackward2>)
# tensor(-3.4925e-10, grad_fn=<SumBackward2>)
# tensor(-1.6298e-09, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(9.9476e-14, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# Episode 650	Last length:    12	Average length: 18.01
# tensor(-5.4570e-12, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(7.1054e-14, grad_fn=<SumBackward2>)
# tensor(1.8626e-08, grad_fn=<SumBackward2>)
# tensor(-9.3132e-10, grad_fn=<SumBackward2>)
# tensor(7.1054e-14, grad_fn=<SumBackward2>)
# tensor(2.8422e-14, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-5.9605e-08, grad_fn=<SumBackward2>)
# tensor(-6.5193e-09, grad_fn=<SumBackward2>)
# tensor(-2.7001e-13, grad_fn=<SumBackward2>)
# tensor(2.3842e-07, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(4.0978e-08, grad_fn=<SumBackward2>)
# tensor(-2.7001e-13, grad_fn=<SumBackward2>)
# tensor(-1.8474e-13, grad_fn=<SumBackward2>)
# tensor(-1.8474e-13, grad_fn=<SumBackward2>)
# tensor(-9.3132e-09, grad_fn=<SumBackward2>)
# tensor(2.8422e-14, grad_fn=<SumBackward2>)
# tensor(1.8626e-09, grad_fn=<SumBackward2>)
# tensor(2.8422e-14, grad_fn=<SumBackward2>)
# tensor(-2.2352e-08, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(7.1054e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(8.1855e-12, grad_fn=<SumBackward2>)
# tensor(2.8422e-14, grad_fn=<SumBackward2>)
# tensor(1.1921e-07, grad_fn=<SumBackward2>)
# tensor(-3.2596e-09, grad_fn=<SumBackward2>)
# tensor(-5.1159e-13, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(3.9581e-09, grad_fn=<SumBackward2>)
# tensor(2.8422e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(1.8626e-09, grad_fn=<SumBackward2>)
# tensor(-1.8626e-09, grad_fn=<SumBackward2>)
# tensor(9.3132e-10, grad_fn=<SumBackward2>)
# tensor(-3.1264e-13, grad_fn=<SumBackward2>)
# tensor(0., grad_fn=<SumBackward2>)
# tensor(-2.7001e-13, grad_fn=<SumBackward2>)
# tensor(-2.7001e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# Episode 700	Last length:     9	Average length: 16.37
# tensor(-2.7001e-13, grad_fn=<SumBackward2>)
# tensor(1.6298e-09, grad_fn=<SumBackward2>)
# tensor(3.6380e-11, grad_fn=<SumBackward2>)
# tensor(5.0664e-07, grad_fn=<SumBackward2>)
# tensor(-2.7001e-13, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-3.8369e-13, grad_fn=<SumBackward2>)
# tensor(-5.9605e-08, grad_fn=<SumBackward2>)
# tensor(7.4506e-09, grad_fn=<SumBackward2>)
# tensor(-7.2760e-12, grad_fn=<SumBackward2>)
# tensor(2.6193e-10, grad_fn=<SumBackward2>)
# tensor(1.7881e-07, grad_fn=<SumBackward2>)
# tensor(0., grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.7462e-10, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.8474e-13, grad_fn=<SumBackward2>)
# tensor(-2.2737e-12, grad_fn=<SumBackward2>)
# tensor(5.8208e-10, grad_fn=<SumBackward2>)
# tensor(-6.9849e-10, grad_fn=<SumBackward2>)
# tensor(-1.2224e-09, grad_fn=<SumBackward2>)
# tensor(-6.7055e-08, grad_fn=<SumBackward2>)
# tensor(-6.2528e-13, grad_fn=<SumBackward2>)
# tensor(1.1176e-08, grad_fn=<SumBackward2>)
# tensor(-3.6380e-12, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(1.8626e-09, grad_fn=<SumBackward2>)
# tensor(2.8422e-14, grad_fn=<SumBackward2>)
# tensor(3.8654e-12, grad_fn=<SumBackward2>)
# tensor(-2.3283e-09, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-8.3819e-09, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-2.3283e-09, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(1.6764e-08, grad_fn=<SumBackward2>)
# tensor(-3.7253e-08, grad_fn=<SumBackward2>)
# tensor(8.1491e-10, grad_fn=<SumBackward2>)
# tensor(-3.8369e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-3.1264e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(3.9790e-13, grad_fn=<SumBackward2>)
# tensor(-1.8474e-13, grad_fn=<SumBackward2>)
# tensor(-3.6380e-12, grad_fn=<SumBackward2>)
# Episode 750	Last length:     8	Average length: 14.87
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(7.1054e-14, grad_fn=<SumBackward2>)
# tensor(-3.8369e-13, grad_fn=<SumBackward2>)
# tensor(-5.5879e-09, grad_fn=<SumBackward2>)
# tensor(-1.4901e-08, grad_fn=<SumBackward2>)
# tensor(-7.2760e-11, grad_fn=<SumBackward2>)
# tensor(2.4738e-10, grad_fn=<SumBackward2>)
# tensor(1.8190e-11, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(1.0245e-08, grad_fn=<SumBackward2>)
# tensor(-9.3132e-10, grad_fn=<SumBackward2>)
# tensor(4.3656e-11, grad_fn=<SumBackward2>)
# tensor(-3.1264e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.8474e-13, grad_fn=<SumBackward2>)
# tensor(4.1723e-07, grad_fn=<SumBackward2>)
# tensor(7.2760e-12, grad_fn=<SumBackward2>)
# tensor(8.1002e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(5.9605e-07, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-3.8369e-13, grad_fn=<SumBackward2>)
# tensor(-1.7053e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-1.0232e-12, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-2.0862e-07, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(-2.5580e-13, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-2.9104e-10, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(1.7881e-07, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.8474e-13, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# Episode 800	Last length:     9	Average length: 13.72
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(1.1369e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(7.1054e-14, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-2.7940e-09, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(2.1828e-11, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-1.8626e-09, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-1.7462e-10, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(8.3447e-07, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.3970e-09, grad_fn=<SumBackward2>)
# tensor(-1.7462e-10, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-4.1723e-07, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-7.2760e-12, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-2.9802e-08, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(1.4552e-11, grad_fn=<SumBackward2>)
# tensor(1.7881e-07, grad_fn=<SumBackward2>)
# tensor(2.8422e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-3.8369e-13, grad_fn=<SumBackward2>)
# Episode 850	Last length:    17	Average length: 12.22
# tensor(-1.8474e-13, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-2.9802e-07, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-7.4506e-09, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(3.7253e-08, grad_fn=<SumBackward2>)
# tensor(7.1054e-14, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.8474e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(2.1828e-11, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-1.8474e-13, grad_fn=<SumBackward2>)
# tensor(-1.1642e-10, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(5.8208e-11, grad_fn=<SumBackward2>)
# tensor(0., grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# Episode 900	Last length:    11	Average length: 11.17
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-1.8474e-13, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(-1.8474e-13, grad_fn=<SumBackward2>)
# tensor(7.1054e-14, grad_fn=<SumBackward2>)
# tensor(7.2760e-12, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-1.0232e-12, grad_fn=<SumBackward2>)
# tensor(-5.1223e-09, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-2.7001e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-2.0464e-12, grad_fn=<SumBackward2>)
# tensor(6.3665e-12, grad_fn=<SumBackward2>)
# tensor(-1.8474e-13, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.3411e-07, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(7.1054e-14, grad_fn=<SumBackward2>)
# tensor(4.6566e-10, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.8474e-13, grad_fn=<SumBackward2>)
# tensor(2.9104e-11, grad_fn=<SumBackward2>)
# tensor(1.1369e-11, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(-3.8369e-13, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(9.9476e-14, grad_fn=<SumBackward2>)
# tensor(-9.4587e-11, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-1.8190e-12, grad_fn=<SumBackward2>)
# tensor(-1.8474e-13, grad_fn=<SumBackward2>)
# Episode 950	Last length:    13	Average length: 10.99
# tensor(-3.8369e-13, grad_fn=<SumBackward2>)
# tensor(7.1054e-14, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(0., grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(1.8190e-12, grad_fn=<SumBackward2>)
# tensor(-3.4925e-10, grad_fn=<SumBackward2>)
# tensor(-3.7253e-09, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-3.8369e-13, grad_fn=<SumBackward2>)
# tensor(2.8422e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(2.9802e-08, grad_fn=<SumBackward2>)
# tensor(2.7001e-13, grad_fn=<SumBackward2>)
# tensor(-1.4552e-10, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(5.5879e-09, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(-1.8474e-13, grad_fn=<SumBackward2>)
# tensor(-2.2737e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(2.8422e-14, grad_fn=<SumBackward2>)
# tensor(-1.8474e-13, grad_fn=<SumBackward2>)
# tensor(-1.8474e-13, grad_fn=<SumBackward2>)
# tensor(-1.4211e-14, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-1.2790e-13, grad_fn=<SumBackward2>)
# tensor(-6.5193e-09, grad_fn=<SumBackward2>)
# tensor(2.5580e-13, grad_fn=<SumBackward2>)
# tensor(1.2790e-13, grad_fn=<SumBackward2>)
# tensor(2.9104e-11, grad_fn=<SumBackward2>)
# tensor(4.2633e-14, grad_fn=<SumBackward2>)
# tensor(5.8208e-11, grad_fn=<SumBackward2>)
# tensor(-1.8474e-13, grad_fn=<SumBackward2>)

# %% [markdown]
# Our policy solves the environment prior to reaching 600 episodes.

# %% [markdown]
# ### Plot Results

# %%
window = int(episodes/20)

fig, ((ax1), (ax2)) = plt.subplots(2, 1, sharey=True, figsize=[9,9]);
rolling_mean = pd.Series(policy.reward_history).rolling(window).mean()
std = pd.Series(policy.reward_history).rolling(window).std()
ax1.plot(rolling_mean)
ax1.fill_between(range(len(policy.reward_history)),rolling_mean-std, rolling_mean+std, color='orange', alpha=0.2)
ax1.set_title('Episode Length Moving Average ({}-episode window)'.format(window))
ax1.set_xlabel('Episode'); ax1.set_ylabel('Episode Length')

ax2.plot(policy.reward_history)
ax2.set_title('Episode Length')
ax2.set_xlabel('Episode'); ax2.set_ylabel('Episode Length')

fig.tight_layout(pad=2)
plt.show()
#fig.savefig('results.png')

# %%
env.action_space.sample()
# Out:
# Discrete(2)
